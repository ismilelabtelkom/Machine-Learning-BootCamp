# %% [markdown]
# ##Apa itu Pandas?
#
# Pandas adalah alat penting dalam analisis data yang membantu kita mempersiapkan data sebelum dianalisis. Sebagian besar waktu di proyek pemodelan statistik digunakan untuk mengimpor, membersihkan, memvalidasi, dan mentransformasi dataset. Pandas membantu dalam persiapan data dan memberikan saran umum tentang apa yang harus dan tidak harus dilakukan sebelum data dianalisis.

# %% [markdown]
# https://pandas.pydata.org/

# %% [markdown]
# # World Happiness Report

# %% [markdown]
# Happiness scored according to economic production, social support, etc.

# %% [markdown]
# # Import Library Yang dibutuhkan

# %%
import pandas as pd

# %% [markdown]
# # Prepare Data

# %% [markdown]
# Download Dataset disini ya: https://telkomuniversityofficial-my.sharepoint.com/:u:/g/personal/rozakalfi_student_telkomuniversity_ac_id/EdHJf4_ScbZEsqhuYi1ZenkB_839NBFKHQ8FeTel8D-LWw?e=b3mQF9

# %%
# !unzip '/content/Dataset.zip' -d '/content'
# Out:
# Archive:  /content/Dataset.zip
#   inflating: /content/2015.csv
#   inflating: /content/2016.csv
#   inflating: /content/2017.csv
#   inflating: /content/2018.csv
#   inflating: /content/2019.csv

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %%
pd.read_csv('/content/2019.csv')
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 0               1                   Finland  7.769           1.340
# 1               2                   Denmark  7.600           1.383
# 2               3                    Norway  7.554           1.488
# 3               4                   Iceland  7.494           1.380
# 4               5               Netherlands  7.488           1.396
# ..            ...                       ...    ...             ...
# 151           152                    Rwanda  3.334           0.359
# 152           153                  Tanzania  3.231           0.476
# 153           154               Afghanistan  3.203           0.350
# 154           155  Central African Republic  3.083           0.026
# 155           156               South Sudan  2.853           0.306
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0             1.587                    0.986                         0.596
# ...

# %%
df = pd.read_csv('/content/2019.csv')

# %%
df
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 0               1                   Finland  7.769           1.340
# 1               2                   Denmark  7.600           1.383
# 2               3                    Norway  7.554           1.488
# 3               4                   Iceland  7.494           1.380
# 4               5               Netherlands  7.488           1.396
# ..            ...                       ...    ...             ...
# 151           152                    Rwanda  3.334           0.359
# 152           153                  Tanzania  3.231           0.476
# 153           154               Afghanistan  3.203           0.350
# 154           155  Central African Republic  3.083           0.026
# 155           156               South Sudan  2.853           0.306
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0             1.587                    0.986                         0.596
# ...

# %%
df[['Score','Generosity']]
# Out:
#      Score  Generosity
# 0    7.769       0.153
# 1    7.600       0.252
# 2    7.554       0.271
# 3    7.494       0.354
# 4    7.488       0.322
# ..     ...         ...
# 151  3.334       0.217
# 152  3.231       0.276
# 153  3.203       0.158
# 154  3.083       0.235
# 155  2.853       0.202
#
# [156 rows x 2 columns]

# %%
type(df[['Score','Generosity']])
# Out:
# pandas.core.frame.DataFrame

# %%
df['Score']
# Out:
# 0      7.769
# 1      7.600
# 2      7.554
# 3      7.494
# 4      7.488
#        ...
# 151    3.334
# 152    3.231
# 153    3.203
# 154    3.083
# 155    2.853
# Name: Score, Length: 156, dtype: float64

# %%
df['Score']
# Out:
# 0      7.769
# 1      7.600
# 2      7.554
# 3      7.494
# 4      7.488
#        ...
# 151    3.334
# 152    3.231
# 153    3.203
# 154    3.083
# 155    2.853
# Name: Score, Length: 156, dtype: float64

# %%
type(df['Score'])
# Out:
# pandas.core.series.Series

# %%
df.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410
# ...

# %%
df.head(20)
# Out:
#     Overall rank Country or region  Score  GDP per capita  Social support  \
# 0              1           Finland  7.769           1.340           1.587
# 1              2           Denmark  7.600           1.383           1.573
# 2              3            Norway  7.554           1.488           1.582
# 3              4           Iceland  7.494           1.380           1.624
# 4              5       Netherlands  7.488           1.396           1.522
# 5              6       Switzerland  7.480           1.452           1.526
# 6              7            Sweden  7.343           1.387           1.487
# 7              8       New Zealand  7.307           1.303           1.557
# 8              9            Canada  7.278           1.365           1.505
# 9             10           Austria  7.246           1.376           1.475
# 10            11         Australia  7.228           1.372           1.548
# 11            12        Costa Rica  7.167           1.034           1.441
# ...

# %%
df.tail()
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 151           152                    Rwanda  3.334           0.359
# 152           153                  Tanzania  3.231           0.476
# 153           154               Afghanistan  3.203           0.350
# 154           155  Central African Republic  3.083           0.026
# 155           156               South Sudan  2.853           0.306
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 151           0.711                    0.614                         0.555
# 152           0.885                    0.499                         0.417
# 153           0.517                    0.361                         0.000
# 154           0.000                    0.105                         0.225
# 155           0.575                    0.295                         0.010
#
#      Generosity  Perceptions of corruption
# 151       0.217                      0.411
# ...

# %%
df.tail(20)
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 136           137                     Egypt  4.166           0.913
# 137           138                    Zambia  4.107           0.578
# 138           139                      Togo  4.085           0.275
# 139           140                     India  4.015           0.755
# 140           141                   Liberia  3.975           0.073
# 141           142                   Comoros  3.973           0.274
# 142           143                Madagascar  3.933           0.274
# 143           144                   Lesotho  3.802           0.489
# 144           145                   Burundi  3.775           0.046
# 145           146                  Zimbabwe  3.663           0.366
# 146           147                     Haiti  3.597           0.323
# 147           148                  Botswana  3.488           1.041
# 148           149                     Syria  3.462           0.619
# ...

# %%
df.columns
# Out:
# Index(['Overall rank', 'Country or region', 'Score', 'GDP per capita',
#        'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['Overall rank', 'Country or region', 'Score', 'GDP per capita',
#        'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption'],
#       dtype='object')

# %%
df.values
# Out:
# array([[1, 'Finland', 7.769, ..., 0.596, 0.153, 0.393],
#        [2, 'Denmark', 7.6, ..., 0.592, 0.252, 0.41],
#        [3, 'Norway', 7.554, ..., 0.603, 0.271, 0.341],
#        ...,
#        [154, 'Afghanistan', 3.203, ..., 0.0, 0.158, 0.025],
#        [155, 'Central African Republic', 3.083, ..., 0.225, 0.235, 0.035],
#        [156, 'South Sudan', 2.853, ..., 0.01, 0.202, 0.091]], dtype=object)

# %%
df['Country or region'].unique()
# Out:
# array(['Finland', 'Denmark', 'Norway', 'Iceland', 'Netherlands',
#        'Switzerland', 'Sweden', 'New Zealand', 'Canada', 'Austria',
#        'Australia', 'Costa Rica', 'Israel', 'Luxembourg',
#        'United Kingdom', 'Ireland', 'Germany', 'Belgium', 'United States',
#        'Czech Republic', 'United Arab Emirates', 'Malta', 'Mexico',
#        'France', 'Taiwan', 'Chile', 'Guatemala', 'Saudi Arabia', 'Qatar',
#        'Spain', 'Panama', 'Brazil', 'Uruguay', 'Singapore', 'El Salvador',
#        'Italy', 'Bahrain', 'Slovakia', 'Trinidad & Tobago', 'Poland',
#        'Uzbekistan', 'Lithuania', 'Colombia', 'Slovenia', 'Nicaragua',
#        'Kosovo', 'Argentina', 'Romania', 'Cyprus', 'Ecuador', 'Kuwait',
#        'Thailand', 'Latvia', 'South Korea', 'Estonia', 'Jamaica',
#        'Mauritius', 'Japan', 'Honduras', 'Kazakhstan', 'Bolivia',
#        'Hungary', 'Paraguay', 'Northern Cyprus', 'Peru', 'Portugal',
#        'Pakistan', 'Russia', 'Philippines', 'Serbia', 'Moldova', 'Libya',
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Overall rank                  156 non-null    int64
#  1   Country or region             156 non-null    object
#  2   Score                         156 non-null    float64
#  3   GDP per capita                156 non-null    float64
#  4   Social support                156 non-null    float64
#  5   Healthy life expectancy       156 non-null    float64
#  6   Freedom to make life choices  156 non-null    float64
#  7   Generosity                    156 non-null    float64
#  8   Perceptions of corruption     156 non-null    float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 11.1+ KB

# %%
df.describe()
# Out:
#        Overall rank       Score  GDP per capita  Social support  \
# count    156.000000  156.000000      156.000000      156.000000
# mean      78.500000    5.407096        0.905147        1.208814
# std       45.177428    1.113120        0.398389        0.299191
# min        1.000000    2.853000        0.000000        0.000000
# 25%       39.750000    4.544500        0.602750        1.055750
# 50%       78.500000    5.379500        0.960000        1.271500
# 75%      117.250000    6.184500        1.232500        1.452500
# max      156.000000    7.769000        1.684000        1.624000
#
#        Healthy life expectancy  Freedom to make life choices  Generosity  \
# count               156.000000                    156.000000  156.000000
# mean                  0.725244                      0.392571    0.184846
# std                   0.242124                      0.143289    0.095254
# min                   0.000000                      0.000000    0.000000
# ...

# %% [markdown]
# ## Data Cleaning

# %%
df.isnull()
# Out:
#      Overall rank  Country or region  Score  GDP per capita  Social support  \
# 0           False              False  False           False           False
# 1           False              False  False           False           False
# 2           False              False  False           False           False
# 3           False              False  False           False           False
# 4           False              False  False           False           False
# ..            ...                ...    ...             ...             ...
# 151         False              False  False           False           False
# 152         False              False  False           False           False
# 153         False              False  False           False           False
# 154         False              False  False           False           False
# 155         False              False  False           False           False
#
# ...

# %%
df.isnull().sum()
# Out:
# Overall rank                    0
# Country or region               0
# Score                           0
# GDP per capita                  0
# Social support                  0
# Healthy life expectancy         0
# Freedom to make life choices    0
# Generosity                      0
# Perceptions of corruption       0
# dtype: int64

# %% [markdown]
# ## Korelasi

# %%
df.corr()
# Out:
#                               Overall rank     Score  GDP per capita  \
# Overall rank                      1.000000 -0.989096       -0.801947
# Score                            -0.989096  1.000000        0.793883
# GDP per capita                   -0.801947  0.793883        1.000000
# Social support                   -0.767465  0.777058        0.754906
# Healthy life expectancy          -0.787411  0.779883        0.835462
# Freedom to make life choices     -0.546606  0.566742        0.379079
# Generosity                       -0.047993  0.075824       -0.079662
# Perceptions of corruption        -0.351959  0.385613        0.298920
#
#                               Social support  Healthy life expectancy  \
# Overall rank                       -0.767465                -0.787411
# Score                               0.777058                 0.779883
# GDP per capita                      0.754906                 0.835462
# ...

# %%
import seaborn as sns

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
df

# %% [markdown]
# ## Membuat salinan data

# %%
df_new=df.copy()

# %%
df_new
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 0               1                   Finland  7.769           1.340
# 1               2                   Denmark  7.600           1.383
# 2               3                    Norway  7.554           1.488
# 3               4                   Iceland  7.494           1.380
# 4               5               Netherlands  7.488           1.396
# ..            ...                       ...    ...             ...
# 151           152                    Rwanda  3.334           0.359
# 152           153                  Tanzania  3.231           0.476
# 153           154               Afghanistan  3.203           0.350
# 154           155  Central African Republic  3.083           0.026
# 155           156               South Sudan  2.853           0.306
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0             1.587                    0.986                         0.596
# ...

# %%
df_new.drop(columns=['Generosity'])
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 0               1                   Finland  7.769           1.340
# 1               2                   Denmark  7.600           1.383
# 2               3                    Norway  7.554           1.488
# 3               4                   Iceland  7.494           1.380
# 4               5               Netherlands  7.488           1.396
# ..            ...                       ...    ...             ...
# 151           152                    Rwanda  3.334           0.359
# 152           153                  Tanzania  3.231           0.476
# 153           154               Afghanistan  3.203           0.350
# 154           155  Central African Republic  3.083           0.026
# 155           156               South Sudan  2.853           0.306
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0             1.587                    0.986                         0.596
# ...

# %%
df_new
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 0               1                   Finland  7.769           1.340
# 1               2                   Denmark  7.600           1.383
# 2               3                    Norway  7.554           1.488
# 3               4                   Iceland  7.494           1.380
# 4               5               Netherlands  7.488           1.396
# ..            ...                       ...    ...             ...
# 151           152                    Rwanda  3.334           0.359
# 152           153                  Tanzania  3.231           0.476
# 153           154               Afghanistan  3.203           0.350
# 154           155  Central African Republic  3.083           0.026
# 155           156               South Sudan  2.853           0.306
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0             1.587                    0.986                         0.596
# ...

# %% [markdown]
# ## Menghapus Kolom

# %%
df_new.drop(columns=['Generosity'],inplace=True)

# %%
df_new
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 0               1                   Finland  7.769           1.340
# 1               2                   Denmark  7.600           1.383
# 2               3                    Norway  7.554           1.488
# 3               4                   Iceland  7.494           1.380
# 4               5               Netherlands  7.488           1.396
# ..            ...                       ...    ...             ...
# 151           152                    Rwanda  3.334           0.359
# 152           153                  Tanzania  3.231           0.476
# 153           154               Afghanistan  3.203           0.350
# 154           155  Central African Republic  3.083           0.026
# 155           156               South Sudan  2.853           0.306
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0             1.587                    0.986                         0.596
# ...

# %%
df_new=df_new.drop(columns=['Perceptions of corruption'])

# %%
df_new
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 0               1                   Finland  7.769           1.340
# 1               2                   Denmark  7.600           1.383
# 2               3                    Norway  7.554           1.488
# 3               4                   Iceland  7.494           1.380
# 4               5               Netherlands  7.488           1.396
# ..            ...                       ...    ...             ...
# 151           152                    Rwanda  3.334           0.359
# 152           153                  Tanzania  3.231           0.476
# 153           154               Afghanistan  3.203           0.350
# 154           155  Central African Republic  3.083           0.026
# 155           156               South Sudan  2.853           0.306
#
#      Social support  Healthy life expectancy  Freedom to make life choices
# 0             1.587                    0.986                         0.596
# ...

# %% [markdown]
#  ## Menambahkan Kolom

# %%
df_new

# %%
df_new['year']=2019

# %%
df_new
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 0               1                   Finland  7.769           1.340
# 1               2                   Denmark  7.600           1.383
# 2               3                    Norway  7.554           1.488
# 3               4                   Iceland  7.494           1.380
# 4               5               Netherlands  7.488           1.396
# ..            ...                       ...    ...             ...
# 151           152                    Rwanda  3.334           0.359
# 152           153                  Tanzania  3.231           0.476
# 153           154               Afghanistan  3.203           0.350
# 154           155  Central African Republic  3.083           0.026
# 155           156               South Sudan  2.853           0.306
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0             1.587                    0.986                         0.596
# ...

# %%
df_new['date']=pd.to_datetime('2019-01-01')

# %%
df_new
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 0               1                   Finland  7.769           1.340
# 1               2                   Denmark  7.600           1.383
# 2               3                    Norway  7.554           1.488
# 3               4                   Iceland  7.494           1.380
# 4               5               Netherlands  7.488           1.396
# ..            ...                       ...    ...             ...
# 151           152                    Rwanda  3.334           0.359
# 152           153                  Tanzania  3.231           0.476
# 153           154               Afghanistan  3.203           0.350
# 154           155  Central African Republic  3.083           0.026
# 155           156               South Sudan  2.853           0.306
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0             1.587                    0.986                         0.596
# ...

# %%
df_new['current_date']=pd.to_datetime('today')

# %%
df_new
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 0               1                   Finland  7.769           1.340
# 1               2                   Denmark  7.600           1.383
# 2               3                    Norway  7.554           1.488
# 3               4                   Iceland  7.494           1.380
# 4               5               Netherlands  7.488           1.396
# ..            ...                       ...    ...             ...
# 151           152                    Rwanda  3.334           0.359
# 152           153                  Tanzania  3.231           0.476
# 153           154               Afghanistan  3.203           0.350
# 154           155  Central African Republic  3.083           0.026
# 155           156               South Sudan  2.853           0.306
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0             1.587                    0.986                         0.596
# ...

# %% [markdown]
# ## Mengubah nama kolom

# %%
df.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410
# ...

# %%
df.rename(columns={'Country or region':'Country'})
# Out:
#      Overall rank                   Country  Score  GDP per capita  \
# 0               1                   Finland  7.769           1.340
# 1               2                   Denmark  7.600           1.383
# 2               3                    Norway  7.554           1.488
# 3               4                   Iceland  7.494           1.380
# 4               5               Netherlands  7.488           1.396
# ..            ...                       ...    ...             ...
# 151           152                    Rwanda  3.334           0.359
# 152           153                  Tanzania  3.231           0.476
# 153           154               Afghanistan  3.203           0.350
# 154           155  Central African Republic  3.083           0.026
# 155           156               South Sudan  2.853           0.306
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0             1.587                    0.986                         0.596
# ...

# %%
df.rename(columns={'Country or region':'Country'},inplace=True)

# %%
df
# Out:
#      Overall rank                   Country  Score  GDP per capita  \
# 0               1                   Finland  7.769           1.340
# 1               2                   Denmark  7.600           1.383
# 2               3                    Norway  7.554           1.488
# 3               4                   Iceland  7.494           1.380
# 4               5               Netherlands  7.488           1.396
# ..            ...                       ...    ...             ...
# 151           152                    Rwanda  3.334           0.359
# 152           153                  Tanzania  3.231           0.476
# 153           154               Afghanistan  3.203           0.350
# 154           155  Central African Republic  3.083           0.026
# 155           156               South Sudan  2.853           0.306
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0             1.587                    0.986                         0.596
# ...

# %% [markdown]
# ## Slicing

# %% [markdown]
# Memilih Kolom dan Baris
# Untuk memilih kolom atau baris pada dataset, kita dapat menggunakan fungsi loc[] dan iloc[]. loc[] digunakan untuk memilih berdasarkan label, sedangkan iloc[] digunakan untuk memilih berdasarkan posisi.

# %%
df.loc[0:5]
# Out:
#    Overall rank      Country  Score  GDP per capita  Social support  \
# 0             1      Finland  7.769           1.340           1.587
# 1             2      Denmark  7.600           1.383           1.573
# 2             3       Norway  7.554           1.488           1.582
# 3             4      Iceland  7.494           1.380           1.624
# 4             5  Netherlands  7.488           1.396           1.522
# 5             6  Switzerland  7.480           1.452           1.526
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
# 5                    1.052                         0.572       0.263
#
# ...

# %%
df.iloc[0:1]
# Out:
#    Overall rank  Country  Score  GDP per capita  Social support  \
# 0             1  Finland  7.769            1.34           1.587
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
#
#    Perceptions of corruption
# 0                      0.393

# %%
df.iloc[10:,:8]
# Out:
#      Overall rank                   Country  Score  GDP per capita  \
# 10             11                 Australia  7.228           1.372
# 11             12                Costa Rica  7.167           1.034
# 12             13                    Israel  7.139           1.276
# 13             14                Luxembourg  7.090           1.609
# 14             15            United Kingdom  7.054           1.333
# ..            ...                       ...    ...             ...
# 151           152                    Rwanda  3.334           0.359
# 152           153                  Tanzania  3.231           0.476
# 153           154               Afghanistan  3.203           0.350
# 154           155  Central African Republic  3.083           0.026
# 155           156               South Sudan  2.853           0.306
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 10            1.548                    1.036                         0.557
# ...
